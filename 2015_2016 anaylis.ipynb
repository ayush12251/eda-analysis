# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("2015_16_Statewise_Secondary.csv")

# %%
df.head()
# Out:
#    ac_year  statcd           statname  area_sqkm  tot_population  \
# 0  2015-16       1  Jammu And Kashmir   222236.0        12548.93
# 1  2015-16       2   Himachal Pradesh    55673.0         6856.51
# 2  2015-16       3             Punjab    50362.0        27704.24
# 3  2015-16       4         Chandigarh      114.0         1054.69
# 4  2015-16       5        Uttarakhand    53483.0        10116.75
#
#    urban_population  grwoth_rate  sexratio  sc_population  st_population  ...  \
# 0             20.05        23.71     883.0            7.4           11.9  ...
# 1              8.69        12.81     974.0           25.2            5.7  ...
# 2             29.82        13.73     893.0           31.9            0.0  ...
# 3             76.66        17.10     818.0           18.9            0.0  ...
# 4             21.54        19.17     963.0           18.8            2.9  ...
#
#    tchmed_nr  tchoth_nr  tchse_nr  tchnr_nr  enrc7_py  enrc8_py  enrc9_py  \
# ...

# %%
df.describe()
# Out:
#           statcd      area_sqkm  tot_population  urban_population  \
# count  36.000000      35.000000       35.000000         35.000000
# mean   18.500000   93921.142857    34576.955429         26.776571
# std    10.535654  103754.389960    44422.781183         16.450826
# min     1.000000      32.000000       64.430000          8.360000
# 25%     9.750000    9367.500000     1420.165000         16.435000
# 50%    18.500000   53483.000000    16753.240000         21.990000
# 75%    27.250000  145449.000000    60757.165000         30.965000
# max    36.000000  342239.000000   199581.480000         77.030000
#
#        grwoth_rate     sexratio  sc_population  st_population  literacy_rate  \
# count    35.000000    35.000000      35.000000      35.000000      35.000000
# mean     19.030857   929.285714      11.760000      22.940000      78.648857
# std      11.021898    79.686360       8.670715      29.179648       8.121043
# ...

# %%
cols_to_keep=['ac_year','statname','tot_population','sexratio','sc_population','st_population','literacy_rate','male_literacy_rate',
              'female_literacy_rate','schools','sch_6','sch_r_6','sch_u_6','enr_6','enr_r_6','enr_u_6','tch_6','tch_r_6'
              ,'tch_u_6','sing_cls_sch_6','bldg_6','girls_toilet_6','boys_toilet_6','co_sch6','water_6','electric_6'
              ,'library_6','bndrywall_6','ict_lab_6','pground_6','enrg_6','scsec','scsec_g','schsec','schsec_g','stsec'
              ,'stsec_g','sthsec','sthsec_g','obcsec','obcsec_g','obchsec','obchsec_g','muslim_sec','muslim_sec_g',
              'muslim_hsec','muslim_hsec_g','boys_b13_c8','boys_13_c8','boys_14_c8','boys_15_c8','boys_a15_c8',
              'girls_b13_c8','girls_13_c8','girls_14_c8','girls_15_c8','girls_a15_c8','boys_b13_c9','boys_13_c9',
              'boys_14_c9','boys_15_c9','boys_a15_c9','girls_b13_c9','girls_13_c9','girls_14_c9','girls_15_c9'
              ,'girls_a15_c9','boys_14_c10','boys_15_c10','boys_a15_c10','girls_14_c10','girls_15_c10','girls_a15_c10'
              ,'boys_b15_c11','girls_b15_c11', "boys_15_c11","boys_16_c11","boys_17_c11","girls_15_c11","girls_16_c11","girls_17_c11"]

# %%
df=df[cols_to_keep]

# %%
df=df.drop([3,10,14,15,20,29,35])

# %%
df.ffill()
# Out:
#     ac_year                        statname  tot_population  sexratio  \
# 0   2015-16               Jammu And Kashmir        12548.93     883.0
# 1   2015-16                Himachal Pradesh         6856.51     974.0
# 2   2015-16                          Punjab        27704.24     893.0
# 4   2015-16                     Uttarakhand        10116.75     963.0
# 5   2015-16                         Haryana        25353.08     877.0
# 6   2015-16  Delhi                                 16753.24     866.0
# 7   2015-16  Rajasthan                             68621.01     926.0
# 8   2015-16                   Uttar Pradesh       199581.48     908.0
# 9   2015-16                           Bihar       103804.64     916.0
# 11  2015-16               Arunachal Pradesh         1382.61     920.0
# 12  2015-16                        Nagaland         1980.60     931.0
# 13  2015-16                         Manipur         2721.76     987.0
# ...

# %%
 df=df.assign(boys_c10= df['boys_14_c10']+df['boys_15_c10']+df['boys_a15_c10'])

# %%
df=df.drop(['boys_14_c10','boys_15_c10','boys_a15_c10'],axis=1)

# %%
df=df.assign(girls_c10= df['girls_14_c10']+df['girls_15_c10']+df['girls_a15_c10'])
df=df.drop(['girls_14_c10','girls_15_c10','girls_a15_c10'],axis=1)

# %%
df=df.assign(boys_c9= df['boys_13_c9']+df['boys_14_c9']+df['boys_15_c9']+df['boys_a15_c9'])
df=df.drop(['boys_13_c9','boys_14_c9','boys_15_c9','boys_a15_c9'],axis=1)

# %%
df=df.assign(girls_c9= df['girls_13_c9']+df['girls_14_c9']+df['girls_15_c9']+df['girls_a15_c9'])
df=df.drop(['girls_13_c9','girls_14_c9','girls_15_c9','girls_a15_c9'],axis=1)

# %%
df=df.assign(boys_c8=df['boys_b13_c8']+ df['boys_13_c8']+df['boys_14_c8']+df['boys_15_c8']+df['boys_a15_c8'])
df=df.drop(['boys_b13_c8','boys_13_c8','boys_14_c8','boys_15_c8','boys_a15_c8'],axis=1)

# %%
df=df.assign(girls_c8=df['girls_b13_c8']+ df['girls_13_c8']+df['girls_14_c8']+df['girls_15_c8']+df['girls_a15_c8'])
df=df.drop(['girls_b13_c8','girls_13_c8','girls_14_c8','girls_15_c8','girls_a15_c8'],axis=1)

# %%
df['boys_c9']=df['boys_c9']+df['boys_b13_c9']
df['girls_c9']=df['girls_c9']+df['girls_b13_c9']
df.drop(['boys_b13_c9','girls_b13_c9'],axis=1,inplace=True)

# %%
df=df.assign(boys_c11=df['boys_b15_c11']+df['boys_16_c11']+df['boys_17_c11']+df['boys_15_c11'])
df=df.assign(girls_c11=df['girls_b15_c11']+df['girls_16_c11']+df['girls_17_c11']+df['girls_15_c11'])

# %%
df=df.drop(['boys_b15_c11','girls_b15_c11','boys_16_c11','girls_16_c11','boys_17_c11','girls_17_c11',"girls_15_c11" ,"boys_b15_c11"], axis=1)

# %%
df.reset_index(drop=True,inplace=True)

# %%
student_teacher_ratio= df['tch_6']/df['enr_6']*100
df=df.assign(student_teacher_ratio=student_teacher_ratio)

# %%
literacy_rural_urban=df.melt(id_vars=["statname"], value_vars=["sch_r_6", "sch_u_6"], var_name="category", value_name="count")

# %%
minority_prog=(df["muslim_hsec"]+df["obchsec"]+df["sthsec"]+df["schsec"]).astype(float)/(df["muslim_hsec"]+df["obchsec"]+df["sthsec"]+df["schsec"]+df["scsec"]+df["obcsec"]+df["stsec"]).astype(float)
minority_prog*100
df=df.assign(minority_prog=minority_prog)

# %%
dropout_after10=df["girls_c10"]-df["girls_c11"]
df=df.assign(dropout_after10=dropout_after10)
df[df["dropout_after10"]<0]=0
dropout_ratio=df["dropout_after10"]/df["girls_c10"]
df=df.assign(dropout_ratio=dropout_ratio)
df["dropout_ratio"].fillna(0, inplace=True)

df["dropout_ratio"]=df["dropout_ratio"]*100
df=df[df["statname"]!="0"]
# Out:
# /var/folders/c1/64m_7mb550bgjqlhn84dmch00000gn/T/ipykernel_16871/2173626822.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["dropout_ratio"].fillna(0, inplace=True)

# %%
boys_after_10= df["boys_c10"]-df["boys_c11"]
boys_after_10_ratio=boys_after_10/df["boys_c10"]
df=df.assign(boys_after_10_ratio=boys_after_10_ratio*100)

# %%
toilet=df.melt(id_vars=["statname"], value_vars=['girls_toilet_6','boys_toilet_6'], var_name="facility", value_name="count")

# %%
# Ensure correct dtypes for plotting
df['statname'] = df['statname'].astype(str)
cmap = plt.get_cmap("tab10")

fig, ax = plt.subplots(3,2,figsize=(15,15))

plot_df = df.melt(id_vars=["statname"], value_vars=["ict_lab_6", "electric_6"], var_name="facility", value_name="count")
ax[0,1].set_ylabel("Count")
ax[0,1].set_title("facilities vs State")

sns.barplot(data=plot_df, x="statname", y="count", hue="facility", ax=ax[0,0])
ax[0,0].set_xlabel("State Name")
ax[0,0].set_ylabel("Count")
ax[0,0].set_ylim(min(plot_df["count"]) * 0.9, max(plot_df["count"]) * 1.1)
ax[0,0].tick_params(axis="x", rotation=90)
ax[0,0].set_title("ICT Lab vs Electricity")
fig.tight_layout()
color_teacher=["grey" if c>3.3 else "black" for c in df["student_teacher_ratio"]]  # Example colors for student-teacher ratio

sns.barplot(data=df, x="statname", y="student_teacher_ratio", ax=ax[1,0], palette=color_teacher)
ax[1,0].set_xlabel("State Name")
ax[1,0].set_ylabel("Student-Teacher Ratio")
ax[1,0].tick_params(axis="x", rotation=90)
ax[1,0].set_title("Student-Teacher Ratio vs State")
# Example colors for rural and urban

sns.barplot(data=literacy_rural_urban, x="statname", y="count", hue="category", ax=ax[1,1])
ax[1,1].set_title("Rural vs Urban Literacy Rate")
ax[1,1].set_xlabel("State Name")
ax[1,1].set_ylabel("Count")
ax[1,1].tick_params(axis="x", rotation=90)
ax[1,1].set_title("Rural & Urban Schools vs State")
color_minority=["skyblue" if c>.4 else "lightcoral" for c in df["minority_prog"]]  # Example colors for minority progression


sns.barplot(data=df, x="statname", y="minority_prog", ax=ax[2,0], palette=color_minority)
ax[2,0].set_xlabel("State Name")
ax[2,0].set_ylabel("Minority Progression percentage")
ax[2,0].tick_params(axis="x", rotation=90)
ax[2,0].set_title("Minority Progression vs State")
color_per=["red" if c>50 else "green" for c in df["dropout_ratio"]]  # Example colors for dropout ratio
sns.barplot(data=df, x="statname", y="dropout_ratio", ax=ax[2,1], palette=color_per)
ax[2,1].set_xlabel("State Name")
ax[2,1].set_ylabel("Dropout Ratio percentage")
ax[2,1].tick_params(axis="x", rotation=90)
ax[2,1].set_title("Dropout Ratio of girls after 10th") 
fig.tight_layout()
# Out:
# /var/folders/c1/64m_7mb550bgjqlhn84dmch00000gn/T/ipykernel_16871/1669338178.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="statname", y="student_teacher_ratio", ax=ax[1,0], palette=color_teacher)
# /var/folders/c1/64m_7mb550bgjqlhn84dmch00000gn/T/ipykernel_16871/1669338178.py:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="statname", y="minority_prog", ax=ax[2,0], palette=color_minority)
# /var/folders/c1/64m_7mb550bgjqlhn84dmch00000gn/T/ipykernel_16871/1669338178.py:42: FutureWarning:
#
# ...

# %%
architechture_df = df.melt(id_vars=["statname"], value_vars=['pground_6', "bndrywall_6"], var_name="facility", value_name="count")
fig, ax = plt.subplots(2, 2, figsize=(15,10))
sns.barplot(data=architechture_df, x="statname", y="count", hue="facility", ax=ax[0,0])
ax[0,0].set_xlabel("State Name")
ax[0,0].set_ylabel("no. of schools")
ax[0,0].tick_params(axis="x", rotation=90)
ax[0,0].set_title("Playground vs Boundary Wall")
ax[0,0].legend(title="Facility", loc="upper right", bbox_to_anchor=(1, 1))
water_library_df = df.melt(id_vars=["statname"], value_vars=['water_6', "library_6"], var_name="facility", value_name="count")
sns.barplot(data=water_library_df, x="statname", y="count", hue="facility", ax=ax[0,1])
ax[0,1].set_xlabel("State Name")
ax[0,1].set_ylabel("no. of schools")
ax[0,1].tick_params(axis="x", rotation=90)
ax[0,1].set_title("Water vs Library")
sns.barplot(data=df, x="statname", y="boys_after_10_ratio", ax=ax[1,0], palette=["red" if c>50 else "green" for c in df["boys_after_10_ratio"]])
ax[1,0].set_xlabel("State Name")
ax[1,0].set_ylabel("Dropout Ratio percentage")
ax[1,0].tick_params(axis="x", rotation=90)
ax[1,0].set_title("Dropout Ratio of Boys")
sns.barplot(data=toilet, x="statname", y="count", hue="facility", ax=ax[1,1])
ax[1,1].set_xlabel("State Name")
ax[1,1].set_ylabel("no. of schools")        
ax[1,1].tick_params(axis="x", rotation=90)
ax[1,1].set_title("Boys vs girls toilet facility")
fig.suptitle("Facilities vs State", fontsize=16)

fig.tight_layout()
# Out:
# /var/folders/c1/64m_7mb550bgjqlhn84dmch00000gn/T/ipykernel_16871/2413882193.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="statname", y="boys_after_10_ratio", ax=ax[1,0], palette=["red" if c>50 else "green" for c in df["boys_after_10_ratio"]])
